# %% [markdown]
# # Visualization with Seaborn - Employee

# %%
# Import thư viện

# %% [markdown]
# ### Phân tích dữ liệu ban đầu

# %%
# 1. Đọc dữ liệu từ file employee.csv và lưu vào biến employee

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <div class="output_subarea output_html rendered_html output_result"><div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right">
#       <th></th>
#       <th>UNIQUE_ID</th>
#       <th>POSITION_TITLE</th>
#       <th>DEPARTMENT</th>
#       <th>BASE_SALARY</th>
#       <th>RACE</th>
#       <th>EMPLOYMENT_TYPE</th>
#       <th>GENDER</th>
#       <th>EMPLOYMENT_STATUS</th>
#       <th>HIRE_DATE</th>
#       <th>JOB_DATE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>ASSISTANT DIRECTOR (EX LVL)</td>
#       <td>Municipal Courts Department</td>
#       <td>121862.0</td>
#       <td>Hispanic/Latino</td>
#       <td>Full Time</td>
#       <td>Female</td>
#       <td>Active</td>
#       <td>2006-06-12</td>
#       <td>2012-10-13</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>LIBRARY ASSISTANT</td>
#       <td>Library</td>
#       <td>26125.0</td>
#       <td>Hispanic/Latino</td>
#       <td>Full Time</td>
#       <td>Female</td>
#       <td>Active</td>
#       <td>2000-07-19</td>
#       <td>2010-09-18</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>POLICE OFFICER</td>
#       <td>Houston Police Department-HPD</td>
#       <td>45279.0</td>
#       <td>White</td>
#       <td>Full Time</td>
#       <td>Male</td>
#       <td>Active</td>
#       <td>2015-02-03</td>
#       <td>2015-02-03</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>ENGINEER/OPERATOR</td>
#       <td>Houston Fire Department (HFD)</td>
#       <td>63166.0</td>
#       <td>White</td>
#       <td>Full Time</td>
#       <td>Male</td>
#       <td>Active</td>
#       <td>1982-02-08</td>
#       <td>1991-05-25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>ELECTRICIAN</td>
#       <td>General Services Department</td>
#       <td>56347.0</td>
#       <td>White</td>
#       <td>Full Time</td>
#       <td>Male</td>
#       <td>Active</td>
#       <td>1989-06-19</td>
#       <td>1994-10-22</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# </details>

# %%
# 2. Thể hiện biểu đồ thống kê số lượng nhân viên theo đơn vị - DEPARTMENT 
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
# <img src="data:image/png;base64,...
# "></details>

# %%
# 3. Thống kê 'BASE_SALARY' trung bình theo  'RACE'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <img src="data:image/png;base64,...
# ">
# </details>

# %%
# 4. Thống kê 'BASE_SALARY' trung bình theo  'RACE' và 'GENDER'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#    <img src="data:image/png;base64,...
# ">
# </details>

# %%
# 5.Cho biết phân bố 'BASE_SALARY' thay đổi thế nào theo 'RACE' và GENDER
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#    <img src="data:image/png;base64,...
# ">
# </details>

# %% [markdown]
# ### Phân tích tương quan với Grids

# %%
# 6.Tạo thêm cột 'YEARS_EXPERIENCE' cho biết số năm thâm niên, tính từ ngày vào làm 'HIRE_DATE' cho đến ngày '12-01-2020'

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <div class="output_subarea output_html rendered_html output_result"><div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right">
#       <th></th>
#       <th>HIRE_DATE</th>
#       <th>YEARS_EXPERIENCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2006-06-12</td>
#       <td>14.472576</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2000-07-19</td>
#       <td>20.370028</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015-02-03</td>
#       <td>5.826266</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1982-02-08</td>
#       <td>38.812570</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1989-06-19</td>
#       <td>31.453076</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# </details>

# %%
# 7.Thực hiện biểu đồ thể hiện sự tương quan giữa 'YEARS_EXPERIENCE' và 'BASE_SALARY'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <img src="data:image/png;base64,...
# ">
# </details>

# %%
# 8.Thực hiện biểu đồ thể hiện sự tương quan giữa 'YEARS_EXPERIENCE' và 'BASE_SALARY', 'GENDER'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <img src="data:image/png;base64,...
# ">
# </details>

# %%
# 9.Thực hiện biểu đồ thể hiện sự tương quan giữa 'YEARS_EXPERIENCE' và 'BASE_SALARY', 'GENDER', 'RACE'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <img src="data:image/png;base64,...
# ">
# </details>

# %%
# 10.Hai câu sau sẽ phân tích 2 đơn vị đông nhân viên nhất (HPD|HFD) và 3 nhóm (White,Hispanic/Latino,Black or African American) của RACE 
# Bây giờ hãy tạo biến emp2 để chứa dữ liệu phân tích cho các câu sau (emp2.shape = (968, 11) )

# %%
# 11. Thực hiện biểu đồ violinplot thể hiện phân bố dữ liệu của 'YEARS_EXPERIENCE' qua  'GENDER' của emp2
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#     <img src="...">
# </details>

# %%
# 12. Thực hiện biểu đồ factorplot - violin thể hiện phân bố dữ liệu của 'YEARS_EXPERIENCE' qua  'GENDER', 'RACE' và 'DEPARTMENT'
# Bạn nhận xét gì qua biểu đồ này

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
# <img src="...">
# </details>
