# %%
import numpy as np
import pandas as pd

# %%
df1= pd.read_csv('data\ex1.csv')
df1
# Out:
#   number  a   b     c   d message
# 0    one  1   2   3.0   4     NaN
# 1    two  5   6   NaN   8   hello
# 2  three  9  10  11.0  12   world

# %%
df1= pd.read_csv('data\ex1.txt',sep='\t')
df1
# Out:
#   number  a   b     c   d message
# 0    one  1   2   3.0   4     NaN
# 1    two  5   6   NaN   8   hello
# 2  three  9  10  11.0  12   world

# %%
# Đọc hết dữ liệu
df2 = pd.read_csv('data\daily_weather.csv', sep=',')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   number                  1095 non-null   int64
#  1   air_pressure_9am        1092 non-null   float64
#  2   air_temp_9am            1090 non-null   float64
#  3   avg_wind_direction_9am  1091 non-null   float64
#  4   avg_wind_speed_9am      1092 non-null   float64
#  5   max_wind_direction_9am  1092 non-null   float64
#  6   max_wind_speed_9am      1091 non-null   float64
#  7   rain_accumulation_9am   1089 non-null   float64
#  8   rain_duration_9am       1092 non-null   float64
#  9   relative_humidity_9am   1095 non-null   float64
#  10  relative_humidity_3pm   1095 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 94.2 KB

# %%
# Đọc file và xác định index_col, nrows
# index_col: cột dùng làm index, có thể là chỉ số cột (index ngầm hiểu) hoặc nhãn cột
df2 = pd.read_csv('daily_weather.csv', index_col =0,nrows=100) # tương đương index_col = 'number' 
print(df2.shape, type(df2))
# Out:
# (100, 10) <class 'pandas.core.frame.DataFrame'>

# %%
df2.head()
# Out:
#         air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# number
# 0             918.060000     74.822000              271.100000
# 1             917.347688     71.403843              101.935179
# 2             923.040000     60.638000               51.000000
# 3             920.502751     70.138895              198.832133
# 4             921.160000     44.294000              277.800000
#
#         avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# number
# 0                 2.080354              295.400000            2.863283
# 1                 2.443009              140.471549            3.533324
# 2                17.067852               63.700000           22.100967
# 3                 4.337363              211.203341            5.190045
# 4                 1.856660              136.500000            2.863283
#
#         rain_accumulation_9am  rain_duration_9am  relative_humidity_9am  \
# number
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 10 columns):
# air_pressure_9am          100 non-null float64
# air_temp_9am              99 non-null float64
# avg_wind_direction_9am    100 non-null float64
# avg_wind_speed_9am        100 non-null float64
# max_wind_direction_9am    100 non-null float64
# max_wind_speed_9am        100 non-null float64
# rain_accumulation_9am     100 non-null float64
# rain_duration_9am         100 non-null float64
# relative_humidity_9am     100 non-null float64
# relative_humidity_3pm     100 non-null float64
# dtypes: float64(10)
# memory usage: 8.6 KB

# %%
df2.describe(include='all')
# Out:
#        air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# count        100.000000     99.000000              100.000000
# mean         919.048823     64.134197              145.220270
# std            3.123951     12.384843               64.850380
# min          911.000000     38.138000               36.174175
# 25%          916.787500     53.735000               71.576483
# 50%          918.825168     65.876000              168.050000
# 75%          921.431097     73.338939              183.925000
# max          927.610000     91.112000              277.800000
#
#        avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# count          100.000000              100.000000          100.000000
# mean             5.497157              153.952431            6.944654
# std              4.548980               64.558226            5.461645
# min              0.939515               37.400000            1.482194
# ...

# %%
# Ghi file csv
df3 = df2.loc[df2['rain_duration_9am'] > 0]
print(df3)
df3.to_csv(r'data\rain_duration_9am.csv')
# Out:
#         air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# number
# 2             923.040000     60.638000               51.000000
# 4             921.160000     44.294000              277.800000
# 5             915.300000     78.404000              182.800000
# 11            915.640000     45.716000              241.600000
# 27            914.900000     78.620000              203.300000
# 38            914.660000     50.360000              177.600000
# 42            921.500000     49.550000               90.700000
# 46            917.900000     65.660000              183.700000
# 55            916.420000     45.014000               82.800000
# 61            918.540000     46.652000              213.600000
# 71            925.097126     57.133499               52.968933
# 72            920.742823     74.515376               51.422719
# 74            922.790000     53.978000              182.600000
# 85            916.820000     50.288000               73.700000
# ...

# %%
# Đọc file Excel

df3 = pd.read_excel('first_data_excel.xlsx', index_col = 0, encoding='utf-8')
print(df3.shape, type(df3))
# Out:
# (5, 3) <class 'pandas.core.frame.DataFrame'>

# %%
print(df3)

# %%
# Đọc file Excel có nhiều sheet
df4 = pd.read_excel('data\movies.xlsx', 'movies')
print(df4.shape, type(df4))
## nếu muốn đọc nhiều sheet trong file thì dùng hàm pd.ExcelFile trước 
#xlsx = pd.ExcelFile('data\movies.xlsx')
#df4 = pd.read_excel(xlsx, 'movies')
print(df4.head())
# Out:
# (9125, 3) <class 'pandas.core.frame.DataFrame'>
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Ghi file Excel
df5 = df4.head(10)
df5.to_excel(r'data\movies_sub.xlsx', "movies")
