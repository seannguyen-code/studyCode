# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data\du_lieu_4.xlsx')
print(df.shape, type(df))
# Out:
# (11, 3) <class 'pandas.core.frame.DataFrame'>

# %%
#df['Height'] = df['Height'] * 0.0254
#df['Weight'] = df['Weight'] *  0.453592
print(df)
# Out:
#     Height  Weight    Age
# 0       74     180  22.99
# 1       74     215  34.69
# 2       72     210  30.78
# 3       72     210  35.43
# 4       73     188  35.71
# 5       69     176  29.39
# 6       69     209  30.77
# 7       71     200  35.07
# 8       76     231  30.19
# 9       71     180  27.05
# 10      73     188  23.88

# %%
df.plot.bar()

# %%
df['Weight'].plot.bar()

# %%
df.plot.box()

# %%
df["Age"].plot.box()

# %%
df.plot.hist()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A49862CB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A497273F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002A4971F1DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A498554F28>]],
#       dtype=object)

# %%
df['Weight'].plot.hist()

# %%
df['Height'].plot.hist(bins=10)

# %%
df.plot()

# %%
df['Height'].plot()

# %%
df['Height'].plot.pie()

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2015', periods=100))
ts.plot()

# %%
a=np.array([0,3,2,5,1])
print(a)
print(a[::-1])
# Out:
# [0 3 2 5 1]
# [1 5 2 3 0]

# %%
print(a)
# Out:
# [0 3 2 5 1]

# %%
b=a[::-1].copy()
print(b)
b[1]=10
print(a)
# Out:
# [1 5 2 3 0]
# [0 3 2 5 1]
