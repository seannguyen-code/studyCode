# %% [markdown]
# ## Bài làm thêm 3.1 : Phân tích lượng mưa ở Seattle
# Một nhóm các nhà khoa học đã thu thập dữ liệu về lượng mưa trung bình hàng tháng ở Seattle (*được đo bằng inch*) như sau:

# %% [markdown]
# |Month|Avg. Precipitation|
# |---:|:---:|
# |January|5.21|
# |February|3.76|
# |March|3.27|
# |April|2.35|
# |May|1.89|
# |June|1.55|
# |July|0.65|
# |August|1.06|
# |September|1.72|
# |October|3.36|
# |November|4.82|
# |December|5.11|

# %%
import numpy as np

# %%
# Tạo numpy array rainfall từ bảng dữ liệu trên

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#
#  <pre>array([5.21, 3.76, 3.27, 2.35, 1.89, 1.55, 0.65, 1.06, 1.72, 3.35, 4.82,
#        5.11])</pre>
#
# </details>

# %%
# Tính trung bình lượng mưa trung bình trong năm tại Seattle

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#
#  <pre>2.895</pre>
#
# </details>

# %%
# Hãy cho biết lượng mưa trung bình ở những tháng giữa năm (cuối mùa Xuân và đầu mùa hè) tại Seattle

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#
#  <pre>2.81</pre>
#
# </details>

# %%
# Xác định độ lệch chuẩn của rainfall

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả !</summary>
#
#  <pre>1.5267312577311483</pre>
#
# </details>

# %%
# Cho biết lượng mưa cao nhất, thấp nhất tại Seatle
