# %% [markdown]
# # Chapter 2 : Sử dụng Markdown

# %% [markdown]
# ### Bài tập 2.2: Viết tiểu sử ngắn về một nhà khoa học mà bạn yêu thích, có kèm hình ảnh của nhà khoa học và link đến trang Wikipedia của họ
# #### cú pháp Markdown sử dụng trong bài tập
# <pre>
# - Tạo liên kết: [nội dung mô tả](link trang web)
# - Chèn hình ảnh: ![nội dung mô tả](link hình)
# - Tạo danh sách:
#    * nội dung 1
#    * nội dung 2
#    * nội dung 3
# </pre>
#
# ##### Sử dụng dữ liệu được cung cấp sau đây để mô tả tiểu sử của nhà khoa học Thomas Alva Edison:

# %% [markdown]
# <details>
#
# ## > Indented block ![alt text](![alt text](https://))
#
#
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#  <p><img src="data:image/jpeg;base64,..." alt="Tiểu sử của nhà khoa học Thomas Alva Edison"></p>
#
# </details>

# %%
Thomas Alva Edison (February 11, 1847 – October 18, 1931)
Link hình: (https://cdn-images-1.medium.com/max/1000/1*s2GyMoLeSV3Epc2Gk3qBXA.png)
Visit Thomas Edison Wikipedia (https://en.wikipedia.org/wiki/Thomas_Edison)
Born: Thomas Alva Edison, February 11, 1847, Milan, Ohio, U.S.
Died: October 18, 1931 (aged 84), West Orange, New Jersey, U.S. 
Burial place: Thomas Edison National Historical Park, Nationality American
Education: Self-educated
Occupation: Inventor, businessman
# Out:
#   File "<ipython-input-1-786321ce6d42>", line 1
#     Thomas Alva Edison (February 11, 1847 – October 18, 1931)
#               ^
# SyntaxError: invalid syntax
