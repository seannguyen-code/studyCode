# %% [markdown]
# # Chapter 2 : Sử dụng Markdown

# %% [markdown]
# ### Bài tập 2.4: Sử dụng Markdown để thực hiện các công thức
#
# #### cú pháp Markdown sử dụng trong bài tập
# $\sum$:   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;   \sum
#
# $\sum_{i=1}^{10} t_i$:    &nbsp;&nbsp; \sum_{i=1}^{10} t_i
#
# $e = \frac{a + b}{c + d}$: &nbsp;&nbsp;&nbsp;e = \frac{a + b}{c + d}
#
# $\in$: &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; \in

# %% [markdown]
# #### Sử dụng các cú pháp Markdown để tạo các công thức theo yêu cầu như hình sau:
#
#  <p><img src="data:image/jpeg;base64,..." alt="Công thức toán học"></p>

# %% [markdown]
# ### Linenear Regression

# %% [markdown]
# a =

# %% [markdown]
# b =

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# * Entropy using the frequency table of one attribute:

# %% [markdown]
# E(S) =

# %% [markdown]
# * Entropy using the frequency table of two attributes:

# %% [markdown]
# E(T, X) =

# %% [markdown]
# * Gain

# %% [markdown]
# Gain(T, X) =
